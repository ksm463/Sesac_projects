# %% [markdown]
# # ML용 데이터 전처리

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data/done/final.csv', encoding='cp949')
df
# Out:
#         년     지역  면적 (ha)  10a당 생산량 (kg)  생산량 (톤)  평균기온(℃)  최고기온 평균(℃)  \
# 0    1980    강원도     1408            609     8574     15.6        21.0
# 1    1980    경기도     3723            406    15116     16.3        22.0
# 2    1980   경상남도     1786            600    10718     17.5        22.5
# 3    1980   경상북도    22667           1132   256590     16.7        21.9
# 4    1980  광주광역시        0              0        0     17.6        22.9
# ..    ...    ...      ...            ...      ...      ...         ...
# 633  2021   전라남도      208            787     1635     19.7        24.4
# 634  2021   전라북도     2033           1729    35142     19.1        24.7
# 635  2021    제주도        0              0        0     21.1        24.4
# 636  2021   충청남도     1551           1711    22757     19.0        24.5
# 637  2021   충청북도     3594           1451    52133     18.5        24.1
#
#      최저기온 평균(℃)  강수량(mm)  합계일조시간(hr)  ...  sp최저기온 평균(℃)  sp강수량(mm)  su평균기온(℃)  \
# 0          10.8   1080.5       264.1  ...           0.5      800.0       19.7
# 1          11.2    474.1       238.4  ...           0.8      397.5       19.9
# 2          12.9   1726.3       228.8  ...           4.0     1093.0       20.7
# 3          12.1   1368.3       239.6  ...           2.6      880.4       20.4
# 4          13.1    208.3       177.2  ...           3.8      133.4       20.9
# ..          ...      ...         ...  ...           ...        ...        ...
# 633        15.7   2292.8       224.7  ...           6.6     1328.2       22.0
# 634        14.4   1532.2       212.0  ...           5.0      673.7       21.7
# 635        18.3    881.0       209.0  ...          10.5      500.0       22.8
# 636        14.3    981.0       214.1  ...           4.6      533.7       21.7
# 637        13.5    738.9       203.3  ...           4.2      372.0       21.3
#
#      su최고기온 평균(℃)  su최저기온 평균(℃)  su강수량(mm)  fa평균기온(℃)  fa최고기온 평균(℃)  \
# 0            25.1          14.9     1167.3       18.6          23.8
# 1            25.3          15.1      550.6       20.2          25.8
# 2            25.7          16.1     1810.9       20.8          25.4
# 3            25.5          15.7     1469.3       20.0          24.6
# 4            25.9          16.5      217.7       21.3          26.4
# ..            ...           ...        ...        ...           ...
# 633          26.5          18.0     2765.2       24.3          28.4
# 634          27.2          17.1     1525.6       23.5          28.3
# 635          26.1          20.1      680.4       25.6          28.4
# 636          27.0          17.1      868.0       23.4          28.0
# 637          26.8          16.4      753.6       22.4          27.0
#
#      fa최저기온 평균(℃)  fa강수량(mm)
# 0            14.8     1230.9
# 1            15.7      436.0
# 2            17.0     2232.6
# 3            16.2     1704.6
# 4            17.4      269.1
# ..            ...        ...
# 633          21.2     2548.9
# 634          19.8     2400.6
# 635          23.3     1563.0
# 636          19.6     1597.8
# 637          18.6     1083.6
#
# [638 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['년', '지역', '면적 (ha)', '10a당 생산량 (kg)', '생산량 (톤)', '평균기온(℃)',
#        '최고기온 평균(℃)', '최저기온 평균(℃)', '강수량(mm)', '합계일조시간(hr)', '합계전천일사량(MJ/㎡)',
#        '평균상대습도(%)', '최소상대습도(%)', '평균풍속(m/s)', '최대풍속(m/s)', '평균현지기압(hPa)',
#        '평균해면기압(hPa)', '최고해면기압(hPa)', '최저해면기압(hPa)', 'sp평균기온(℃)',
#        'sp최고기온 평균(℃)', 'sp최저기온 평균(℃)', 'sp강수량(mm)', 'su평균기온(℃)',
#        'su최고기온 평균(℃)', 'su최저기온 평균(℃)', 'su강수량(mm)', 'fa평균기온(℃)',
#        'fa최고기온 평균(℃)', 'fa최저기온 평균(℃)', 'fa강수량(mm)'],
#       dtype='object')

# %%
fig, axe1 = plt.subplots()
axe2 = axe1.twinx()

a1 = sns.lineplot(ax=axe1, x=df[df['지역'] == '경상북도']['년'], y=df[df['지역'] == '경상북도']['평균기온(℃)'], color='crimson')
a2 =sns.lineplot(ax=axe2, x=df[df['지역'] == '경상북도']['년'], y=df[df['지역'] == '경상북도']['10a당 생산량 (kg)'], color='steelblue')

fig.legend(['평균기온(℃)', '10a당 생산량 (kg)'])

axe1.set_ylabel('평균기온(℃)')
axe2.set_ylabel('10a당 생산량 (kg)')
# Out:
# Text(0, 0.5, '10a당 생산량 (kg)')

# %%
# df[['면적 (ha)', '10a당 생산량 (kg)', '생산량 (톤)']].astype(float)

# %%
# data = df.drop(df[df['지역'] == '경상북도'].index)

# %%
round(df.groupby('지역').mean(), 1)['생산량 (톤)'].sort_values(ascending=False)
# Out:
# 지역
# 경상북도     332892.1
# 충청북도      59498.8
# 충청남도      44873.2
# 경상남도      36078.2
# 전라북도      18634.6
# 경기도       11493.8
# 강원도        5433.4
# 전라남도       3552.5
# 대구광역시      2731.7
# 대전광역시       590.2
# 울산광역시       157.4
# 인천광역시        47.1
# 서울특별시        11.9
# 부산광역시        11.5
# 광주광역시         3.2
# 제주도           0.0
# Name: 생산량 (톤), dtype: float64

# %%
locs = ['경상북도']
data = pd.DataFrame()
for idx, loc in enumerate(locs):
    tmp = df[df['지역'] == locs[idx]]
    data = pd.concat([data, tmp])

data = data.drop(data[data['생산량 (톤)'] == 0].index)
data = data[['10a당 생산량 (kg)', '합계일조시간(hr)', '평균기온(℃)', '최고기온 평균(℃)', '최저기온 평균(℃)', '강수량(mm)',
       '평균상대습도(%)', '최소상대습도(%)', '평균풍속(m/s)', '최대풍속(m/s)', '평균현지기압(hPa)',
       '평균해면기압(hPa)', '최고해면기압(hPa)', '최저해면기압(hPa)', 'sp평균기온(℃)',
       'sp최고기온 평균(℃)', 'sp최저기온 평균(℃)', 'sp강수량(mm)', 'su평균기온(℃)',
       'su최고기온 평균(℃)', 'su최저기온 평균(℃)', 'su강수량(mm)', 'fa평균기온(℃)',
       'fa최고기온 평균(℃)', 'fa최저기온 평균(℃)', 'fa강수량(mm)']]

# %%
# data = df.drop(df[df['생산량 (톤)'] == 0].index)
# data = data[['10a당 생산량 (kg)', '합계일조시간(hr)',
#        '평균상대습도(%)', '최소상대습도(%)', '평균풍속(m/s)', '최대풍속(m/s)', '평균현지기압(hPa)',
#        '평균해면기압(hPa)', '최고해면기압(hPa)', '최저해면기압(hPa)', 'sp평균기온(℃)',
#        'sp최고기온 평균(℃)', 'sp최저기온 평균(℃)', 'sp강수량(mm)', 'su평균기온(℃)',
#        'su최고기온 평균(℃)', 'su최저기온 평균(℃)', 'su강수량(mm)', 'fa평균기온(℃)',
#        'fa최고기온 평균(℃)', 'fa최저기온 평균(℃)', 'fa강수량(mm)']]

# %%
# data = df[['10a당 생산량 (kg)', '합계일조시간(hr)',
#        '평균상대습도(%)', '최소상대습도(%)', '평균풍속(m/s)', '최대풍속(m/s)', '평균현지기압(hPa)',
#        '평균해면기압(hPa)', '최고해면기압(hPa)', '최저해면기압(hPa)', 'sp평균기온(℃)',
#        'sp최고기온 평균(℃)', 'sp최저기온 평균(℃)', 'sp강수량(mm)', 'su평균기온(℃)',
#        'su최고기온 평균(℃)', 'su최저기온 평균(℃)', 'su강수량(mm)', 'fa평균기온(℃)',
#        'fa최고기온 평균(℃)', 'fa최저기온 평균(℃)', 'fa강수량(mm)']]

# %%
data
# Out:
#      10a당 생산량 (kg)  합계일조시간(hr)  평균기온(℃)  최고기온 평균(℃)  최저기온 평균(℃)  강수량(mm)  \
# 3             1132       239.6     16.7        21.9        12.1   1368.3
# 17            1440       255.7     17.6        23.2        12.4   1057.6
# 28            1392       268.6     17.9        23.5        12.6    723.4
# 41            1622       252.4     18.0        23.4        13.1   1351.1
# 55            1516       258.4     17.4        22.8        12.6   1317.4
# 69            1532       245.1     18.0        23.1        13.3   1402.2
# 83            1595       251.3     17.0        22.4        12.3   1058.1
# 96            1464       255.2     17.2        22.8        12.3   1304.6
# 111           1481       250.3     17.2        22.7        12.2   1219.1
# 126           1399       254.9     17.4        23.0        12.4   1419.3
# 141           1303       242.5     18.0        23.4        13.4   1510.4
# 156           1106       242.6     17.3        22.6        12.4   1629.6
# 167           1315       234.3     17.4        22.8        12.4   1241.5
# 182           1154       205.1     16.3        21.9        11.4   1824.4
# 197           1120       244.2     18.6        24.7        12.9    846.9
# 212           1421       224.2     17.4        23.2        12.1   1163.8
# 227           1514       219.1     17.2        22.9        12.1   1238.6
# 242           1688       228.4     17.9        23.8        12.6   1449.2
# 257           1358       184.7     18.2        23.3        13.7   2144.8
# 273           1541       212.5     17.8        23.2        13.0   2146.5
# 289           1682       218.7     17.9        23.7        12.8   1494.7
# 305           1439       340.2     18.0        24.1        12.7   1010.7
# 321           1650       237.5     17.5        23.1        12.6   2109.5
# 337           1376       215.8     16.9        22.0        12.5   2814.3
# 353           1306       237.4     18.1        23.8        13.0   2138.0
# 369           1310       240.0     18.0        23.6        13.0   1735.2
# 385           1374       221.8     17.3        22.8        12.6   2005.2
# 401           1425       205.7     17.9        23.2        13.3   1997.9
# 417           1445       203.1     18.1        23.7        13.1   1312.7
# 433           1575       200.8     18.0        23.7        12.9   1417.9
# 449           1498       194.9     17.9        23.3        13.3   1564.1
# 465           1237       193.7     17.6        23.1        12.8   2074.3
# 481           1323       207.6     18.1        23.5        13.4   2150.5
# 497           1636       235.2     18.5        24.4        13.3   1492.4
# 513           1554       219.2     18.1        23.9        13.0   1780.1
# 529           1936       241.9     18.1        24.1        12.7   1105.5
# 545           1831       240.6     18.9        24.6        13.9   1861.4
# 561           1675       257.8     18.7        24.8        13.4   1407.3
# 577           1594       236.8     19.1        24.8        14.0   1991.0
# 593           1737       238.7     18.6        24.4        13.4   1583.0
# 609           1486       227.5     18.1        23.6        13.3   2291.8
# 625           1475       208.1     18.3        23.6        13.7   2026.7
#
#      평균상대습도(%)  최소상대습도(%)  평균풍속(m/s)  최대풍속(m/s)  ...  sp최저기온 평균(℃)  sp강수량(mm)  \
# 3         77.4       38.4        2.1       10.7  ...           2.6      880.4
# 17        75.1       39.3        2.1       10.0  ...           3.2      366.7
# 28        74.7       36.3        2.1       10.7  ...           3.5      417.9
# 41        77.6       38.3        2.3       11.7  ...           3.6      926.8
# 55        79.7       38.4        2.0       10.1  ...           1.4      683.6
# 69        81.1       40.1        2.1       10.1  ...           3.1      640.7
# 83        79.1       37.4        2.1       10.8  ...           2.6      331.9
# 96        81.7       43.6        2.3       12.6  ...           2.6      453.3
# 111       78.6       38.4        2.2        9.5  ...           1.8      512.0
# 126       78.7       36.7        2.2       10.3  ...           3.2      728.8
# 141       81.9       42.6        2.1        9.4  ...           3.4      751.8
# 156       83.9       51.9        2.0       10.3  ...           2.4      755.2
# 167       84.1       52.4        2.1        9.6  ...           3.7      815.6
# 182       83.6       51.9        2.1        9.6  ...           1.9      536.4
# 197       78.9       51.0        2.2        9.3  ...           2.6      356.8
# 212       81.3       51.4        2.1        8.9  ...           2.3      703.6
# 227       81.7       53.0        1.9        7.9  ...           1.6      945.6
# 242       80.7       51.4        2.0        8.3  ...           3.2      424.8
# 257       82.1       50.4        2.0        8.4  ...           5.6      845.0
# 273       82.6       42.6        2.1       10.3  ...           3.2     1038.6
# 289       76.3       27.7        2.0       11.0  ...           2.8      430.2
# 305       76.0       28.6        2.1        8.4  ...           2.3      163.8
# 321       80.3       33.6        2.0        9.0  ...           4.0     1127.6
# 337       83.6       35.0        1.8        8.9  ...           3.4     1463.6
# 353       74.4       26.1        2.0        9.3  ...           3.1      756.7
# 369       76.4       33.7        2.1        8.9  ...           2.6      694.8
# 385       78.9       35.6        2.1        9.4  ...           2.6      728.0
# 401       78.9       35.6        2.0        9.1  ...           3.4      757.3
# 417       76.9       30.7        2.1        8.1  ...           3.8      538.7
# 433       75.1       28.3        2.0        8.3  ...           3.6      596.8
# 449       78.1       32.4        2.0        8.2  ...           2.2      782.2
# 465       76.9       28.6        2.2        8.6  ...           1.6      835.5
# 481       80.1       34.1        2.1        9.2  ...           3.4     1304.2
# 497       78.6       32.0        2.0        8.3  ...           1.9      925.4
# 513       74.3       30.6        2.0        7.8  ...           3.8     1275.7
# 529       74.0       25.9        2.0        8.8  ...           3.2      865.0
# 545       77.0       34.3        2.0        8.2  ...           4.2     1357.2
# 561       74.1       25.6        2.0        7.9  ...           3.9      724.0
# 577       75.7       30.6        2.1        8.1  ...           4.4     1810.5
# 593       77.6       30.3        2.0        8.2  ...           3.4      863.2
# 609       80.4       34.4        2.0        8.9  ...           3.0      421.8
# 625       80.9       36.4        1.8        7.6  ...           4.6     1253.0
#
#      su평균기온(℃)  su최고기온 평균(℃)  su최저기온 평균(℃)  su강수량(mm)  fa평균기온(℃)  \
# 3         20.4          25.5          15.7     1469.3       20.0
# 17        20.9          26.2          15.8      843.7       21.0
# 28        20.8          26.5          15.4      657.1       22.0
# 41        20.4          25.8          15.3     1397.9       23.1
# 55        20.7          26.0          15.9     1406.9       22.9
# 69        20.7          25.9          16.0     1315.0       23.2
# 83        19.7          24.6          15.3     1412.9       21.5
# 96        20.6          26.0          15.3     1610.0       21.2
# 111       20.1          25.2          15.3     1762.9       22.2
# 126       20.0          25.4          15.1     1620.8       21.6
# 141       20.7          25.7          16.4     1854.4       23.0
# 156       20.6          25.6          15.8     1737.4       21.3
# 167       20.0          25.9          14.6     1059.4       21.6
# 182       19.2          24.4          14.7     2169.7       20.2
# 197       21.8          27.7          16.2     1231.4       23.6
# 212       19.9          25.4          14.8      976.9       22.4
# 227       20.2          25.6          15.5     1717.1       22.4
# 242       20.8          26.6          15.8     2226.9       21.8
# 257       20.1          24.8          15.9     2179.7       22.4
# 273       20.3          25.7          15.5     1800.0       22.6
# 289       21.2          27.1          16.1     1292.5       21.6
# 305       21.4          27.2          16.5     1447.1       21.9
# 321       20.1          25.5          15.1     1446.2       20.9
# 337       19.2          24.3          15.0     3404.6       21.5
# 353       21.1          26.5          16.3     2389.0       21.8
# 369       21.0          26.6          16.1     1734.0       22.5
# 385       20.0          25.0          15.6     3388.8       22.2
# 401       20.4          25.7          15.7     1809.1       23.1
# 417       21.0          26.3          16.1     1658.0       22.0
# 433       20.8          26.5          15.9     2172.7       21.8
# 449       21.3          26.9          16.2     1167.7       23.6
# 465       20.9          26.2          16.3     3021.0       22.4
# 481       21.2          26.6          16.5     1640.7       22.4
# 497       21.8          27.4          17.1     1871.1       23.5
# 513       21.3          27.2          16.2      889.4       21.3
# 529       21.2          27.1          15.9     1197.1       22.0
# 545       21.7          27.5          16.6     1733.1       23.3
# 561       22.1          28.2          16.7     1470.1       22.2
# 577       22.0          27.6          17.0     1748.4       23.1
# 593       21.4          27.2          16.0     1581.8       23.4
# 609       20.7          25.8          16.2     2969.3       23.0
# 625       20.9          26.1          16.3     1780.8       22.3
#
#      fa최고기온 평균(℃)  fa최저기온 평균(℃)  fa강수량(mm)
# 3            24.6          16.2     1704.6
# 17           26.3          16.4     2069.4
# 28           27.1          17.6     1128.4
# 41           27.8          19.4     1705.2
# 55           28.0          19.0     1817.0
# 69           27.7          19.6     2294.4
# 83           26.6          17.4     1252.0
# 96           26.2          17.4     1697.8
# 111          27.5          17.8     1110.7
# 126          26.4          17.5     1807.4
# 141          28.3          18.8     1752.8
# 156          26.0          17.4     2342.4
# 167          26.1          17.9     1940.5
# 182          25.4          15.9     2594.4
# 197          29.7          18.2      760.2
# 212          27.8          18.0     1904.4
# 227          28.2          17.6      813.8
# 242          27.4          17.4     1307.2
# 257          27.2          18.6     3392.0
# 273          27.1          19.1     3774.2
# 289          26.4          18.0     2862.4
# 305          27.6          17.4     1202.8
# 321          25.7          17.3     4086.4
# 337          26.1          18.0     3279.4
# 353          26.8          18.1     3143.0
# 369          27.2          19.0     2777.4
# 385          27.6          18.0     1207.0
# 401          27.4          19.8     3521.8
# 417          27.4          17.8     1568.7
# 433          27.0          17.6     1106.8
# 449          28.8          20.0     2940.6
# 465          27.2          18.6     1892.9
# 481          27.4          18.7     3761.6
# 497          29.2          19.1     1491.2
# 513          26.3          17.5     3620.6
# 529          27.8          17.5     1208.8
# 545          28.4          19.4     2558.2
# 561          27.6          17.9     1996.4
# 577          28.2          19.0     2535.4
# 593          28.4          19.5     2304.7
# 609          27.8          19.2     3145.6
# 625          26.8          18.8     3169.4
#
# [42 rows x 26 columns]

# %% [markdown]
# ## 생산량의 분포 확인

# %%
data['10a당 생산량 (kg)'].hist()
# Out:
# <AxesSubplot:>

# %%
y_log_transform = np.log1p(data['10a당 생산량 (kg)'])
y_log_transform.hist()
# Out:
# <AxesSubplot:>

# %%
data['10a당 생산량 (kg)'] = y_log_transform

# %% [markdown]
# # 컬럼별 히트맵

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(9, 9))
corr = data.corr()
sns.heatmap(corr, cmap='RdBu', vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 컬럼이 회귀 결과에 미치는 영향 시각화

# %%
# 각 컬럼이 회귀 결과에 미치는 영향이 어느 정도인지 시각화
data_features = ['합계일조시간(hr)', '평균상대습도(%)', '평균기온(℃)', '최고기온 평균(℃)', '최저기온 평균(℃)', '강수량(mm)',
       '최소상대습도(%)', '평균풍속(m/s)', '최대풍속(m/s)', '평균현지기압(hPa)', '평균해면기압(hPa)',
       '최고해면기압(hPa)', '최저해면기압(hPa)', 'sp평균기온(℃)', 'sp최고기온 평균(℃)',
       'sp최저기온 평균(℃)', 'sp강수량(mm)', 'su평균기온(℃)', 'su최고기온 평균(℃)',
       'su최저기온 평균(℃)', 'su강수량(mm)', 'fa평균기온(℃)', 'fa최고기온 평균(℃)',
       'fa최저기온 평균(℃)', 'fa강수량(mm)']
fig, axs = plt.subplots(figsize=(20, 24), ncols=4, nrows=7)
for i , feature in enumerate(data_features):
    row = int(i / 4)
    col = i % 4
    
    # seaborn의 regplot을 이용해 산점도와 선형 회귀 직선을 함께 표현
    sns.regplot(x=feature, y='10a당 생산량 (kg)', data=data, ax=axs[row][col])

# %% [markdown]
# # 선형 회귀

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso, ElasticNet
from sklearn.preprocessing import StandardScaler, MinMaxScaler, PolynomialFeatures

# %%
y = data['10a당 생산량 (kg)']
X = data.drop(columns='10a당 생산량 (kg)')

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=156)

# %%
# 선형 회귀 OLS로 학습/예측/평가 수행
lr = LinearRegression()
lr.fit(X_train, y_train)
pred = lr.predict(X_test)
mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse) # = mean_squared_error(y_test, pred, squared=False)
print(f'MSE: {mse:.3f}, RMSE: {rmse:.3f}, R2: {r2_score(y_test, pred):.3f}')
# Out:
# MSE: 0.158, RMSE: 0.398, R2: -26.128

# %%
print(f'절편값: {lr.intercept_}')
print(f'회귀 계수값: {np.round(lr.coef_, 1)}')
# Out:
# 절편값: -125.58627008525447
# 회귀 계수값: [ 0.   1.6  2.   5.6  2.1 -0.1  0.  -2.4  0.3  0.   0.  -0.1  0.2  0.1
#  -0.6 -2.1 -0.6 -0.8 -0.7 -2.6 -0.9 -3.1  0.7 -0.1 -0.6]

# %%
# 회귀 계수를 큰 값 순으로 정렬(Serise로 생성)
pd.Series(np.round(lr.coef_, 1), index=X.columns).sort_values(ascending=False)
# Out:
# 최저기온 평균(℃)      5.6
# 강수량(mm)         2.1
# 최고기온 평균(℃)      2.0
# 평균기온(℃)         1.6
# fa최고기온 평균(℃)    0.7
# 최대풍속(m/s)       0.3
# 최저해면기압(hPa)     0.2
# sp평균기온(℃)       0.1
# 평균해면기압(hPa)     0.0
# 합계일조시간(hr)      0.0
# 평균현지기압(hPa)     0.0
# 최소상대습도(%)       0.0
# 최고해면기압(hPa)    -0.1
# 평균상대습도(%)      -0.1
# fa최저기온 평균(℃)   -0.1
# sp최고기온 평균(℃)   -0.6
# sp강수량(mm)      -0.6
# fa강수량(mm)      -0.6
# su최고기온 평균(℃)   -0.7
# su평균기온(℃)      -0.8
# su강수량(mm)      -0.9
# sp최저기온 평균(℃)   -2.1
# 평균풍속(m/s)      -2.4
# su최저기온 평균(℃)   -2.6
# fa평균기온(℃)      -3.1
# dtype: float64

# %%
neg_mse_scores = cross_val_score(lr, X, y, scoring='neg_mean_squared_error', cv=5)
rmse_scores = np.sqrt(-1*neg_mse_scores)
avg_rmse = np.mean(rmse_scores)

print(f'5 folds 개별 Negative MSE scores: {np.round(neg_mse_scores, 2)}')
print(f'5 folds 개별 RMSE scores: {np.round(rmse_scores, 2)}')
print(f'5 folds 평균 RMSE: {np.round(avg_rmse, 3)}')
# Out:
# 5 folds 개별 Negative MSE scores: [-0.06 -0.08 -0.14 -0.06 -0.03]
# 5 folds 개별 RMSE scores: [0.24 0.27 0.37 0.23 0.18]
# 5 folds 평균 RMSE: 0.259

# %%
# 릿지에 사용될 alpha 파라미터 정의
alphas = [0, 0.1, 1, 10, 100]

# alpha list 값을 반복하면서 alpha에 따른 평균 rmse를 구함
for alpha in alphas:
    ridge = Ridge(alpha=alpha)
    
    neg_mse_scores = cross_val_score(ridge, X, y, scoring='neg_mean_squared_error', cv=5)
    avg_rmse = np.mean(np.sqrt(-1*neg_mse_scores))
    print(f'5 folds 평균 RMSE: {np.round(avg_rmse, 3)}')
# Out:
# 5 folds 평균 RMSE: 0.259
# 5 folds 평균 RMSE: 0.18
# 5 folds 평균 RMSE: 0.156
# 5 folds 평균 RMSE: 0.142
# 5 folds 평균 RMSE: 0.133

# %%
# alpha값에 따른 회귀 모델의 폴드 평균 RMSE를 출력하고 회귀 계수값들을 DataFrame으로 반환 
def get_linear_reg_eval(model_name, params=None, X_data_n=None, y_target_n=None, 
                        verbose=True, return_coeff=True):
    coeff_df = pd.DataFrame()
    if verbose : print('####### ', model_name , '#######')
    for param in params:
        if model_name =='Ridge': model = Ridge(alpha=param)
        elif model_name =='Lasso': model = Lasso(alpha=param)
        elif model_name =='ElasticNet': model = ElasticNet(alpha=param, l1_ratio=0.7) # L1과 L2의 비율
        
        # 교차검증, 점수
        neg_mse_scores = cross_val_score(model, X_data_n, 
                                             y_target_n, scoring="neg_mean_squared_error", cv = 5)
        avg_rmse = np.mean(np.sqrt(-1 * neg_mse_scores))
        print('alpha {0}일 때 5 폴드 세트의 평균 RMSE: {1:.3f} '.format(param, avg_rmse))
        
        # cross_val_score는 evaluation metric만 반환하므로 모델을 다시 학습하여 회귀 계수 추출
        model.fit(X_data_n , y_target_n)
        if return_coeff:
            # alpha에 따른 피처별 회귀 계수를 Series로 변환하고 이를 DataFrame의 컬럼으로 추가. 
            coeff = pd.Series(data=model.coef_ , index=X_data_n.columns )
            colname='alpha:' + str(param)
            coeff_df[colname] = coeff

    return coeff_df
# end of get_linear_regre_eval

# %%
lasso_alphas = [0.07, 0.1, 0.5, 1, 3]
coeff_lasso_df = get_linear_reg_eval('Lasso', lasso_alphas, X, y)
# Out:
# #######  Lasso #######
# alpha 0.07일 때 5 폴드 세트의 평균 RMSE: 0.132
# alpha 0.1일 때 5 폴드 세트의 평균 RMSE: 0.132
# alpha 0.5일 때 5 폴드 세트의 평균 RMSE: 0.132
# alpha 1일 때 5 폴드 세트의 평균 RMSE: 0.132
# alpha 3일 때 5 폴드 세트의 평균 RMSE: 0.131

# %%
elastic_alphas = [0.07, 0.1, 0.5, 1, 3]
coeff_elastic_df = get_linear_reg_eval('ElasticNet', elastic_alphas, X, y)
# Out:
# #######  ElasticNet #######
# alpha 0.07일 때 5 폴드 세트의 평균 RMSE: 0.133
# alpha 0.1일 때 5 폴드 세트의 평균 RMSE: 0.132
# alpha 0.5일 때 5 폴드 세트의 평균 RMSE: 0.131
# alpha 1일 때 5 폴드 세트의 평균 RMSE: 0.132
# alpha 3일 때 5 폴드 세트의 평균 RMSE: 0.131

# %%
# method는 표준 정규 분포 변환(Standard), 최대값/최소값 정규화(MinMax), 로그변환(Log) 결정
# p_degree는 다향식 특성을 추가할 때 적용. p_degree는 2이상 부여하지 않음.
def get_scaled_data(method='None', p_degree=None, input_data=None):
    if method == 'Standard':
        scaled_data = StandardScaler().fit_transform(input_data)
    elif method == 'MinMax':
        scaled_data = MinMaxScaler().fit_transform(input_data)
    elif method == 'Log':
        scaled_data = np.log1p(input_data)
    else:
        scaled_data = input_data

    if p_degree != None:
        scaled_data = PolynomialFeatures(degree=p_degree, 
                                         include_bias=False).fit_transform(scaled_data)

    return scaled_data

# %%
alphas = [0.1, 1, 10, 100]

scale_methods = [(None, None), ('Standard', None), ('Standard', 2),
                 ('MinMax', None), ('MinMax', 2), ('Log', None)]
for scale_method in scale_methods:
    X_scaled_data = get_scaled_data(method=scale_method[0], p_degree=scale_method[1], input_data=X)
    print(f'\n## 변환 유형: {scale_method[0]}, Polynomial Degree: {scale_method[1]}')
    get_linear_reg_eval('Ridge', alphas, X_scaled_data, y, return_coeff=False)
# Out:
# ## 변환 유형: None, Polynomial Degree: None
# #######  Ridge #######
# alpha 0.1일 때 5 폴드 세트의 평균 RMSE: 0.180
# alpha 1일 때 5 폴드 세트의 평균 RMSE: 0.156
# alpha 10일 때 5 폴드 세트의 평균 RMSE: 0.142
# alpha 100일 때 5 폴드 세트의 평균 RMSE: 0.133
#
# ## 변환 유형: Standard, Polynomial Degree: None
# #######  Ridge #######
# alpha 0.1일 때 5 폴드 세트의 평균 RMSE: 0.176
# alpha 1일 때 5 폴드 세트의 평균 RMSE: 0.146
# alpha 10일 때 5 폴드 세트의 평균 RMSE: 0.126
# alpha 100일 때 5 폴드 세트의 평균 RMSE: 0.121
#
# ## 변환 유형: Standard, Polynomial Degree: 2
# #######  Ridge #######
# alpha 0.1일 때 5 폴드 세트의 평균 RMSE: 0.219
# alpha 1일 때 5 폴드 세트의 평균 RMSE: 0.217
# alpha 10일 때 5 폴드 세트의 평균 RMSE: 0.202
# alpha 100일 때 5 폴드 세트의 평균 RMSE: 0.166
#
# ## 변환 유형: MinMax, Polynomial Degree: None
# #######  Ridge #######
# alpha 0.1일 때 5 폴드 세트의 평균 RMSE: 0.138
# alpha 1일 때 5 폴드 세트의 평균 RMSE: 0.123
# alpha 10일 때 5 폴드 세트의 평균 RMSE: 0.122
# alpha 100일 때 5 폴드 세트의 평균 RMSE: 0.127
#
# ## 변환 유형: MinMax, Polynomial Degree: 2
# #######  Ridge #######
# alpha 0.1일 때 5 폴드 세트의 평균 RMSE: 0.181
# alpha 1일 때 5 폴드 세트의 평균 RMSE: 0.142
# alpha 10일 때 5 폴드 세트의 평균 RMSE: 0.126
# alpha 100일 때 5 폴드 세트의 평균 RMSE: 0.124
#
# ## 변환 유형: Log, Polynomial Degree: None
# #######  Ridge #######
# alpha 0.1일 때 5 폴드 세트의 평균 RMSE: 0.130
# alpha 1일 때 5 폴드 세트의 평균 RMSE: 0.122
# alpha 10일 때 5 폴드 세트의 평균 RMSE: 0.128
# alpha 100일 때 5 폴드 세트의 평균 RMSE: 0.129

# %% [markdown]
# # 회귀 트리

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# log 값 변환 시 NaN등의 이슈로 log() 가 아닌 log1p() 를 이용하여 RMSLE 계산
def rmsle(y, pred):
    log_y = np.log1p(y)
    log_pred = np.log1p(pred)
    squared_error = (log_y - log_pred) ** 2
    rmsle = np.sqrt(np.mean(squared_error))
    return rmsle

# 사이킷런의 mean_square_error() 를 이용하여 RMSE 계산
def rmse(y,pred):
    return np.sqrt(mean_squared_error(y,pred))

# MSE, RMSE, RMSLE 를 모두 계산 
def evaluate_regr(y,pred):
    rmsle_val = rmsle(y,pred)
    rmse_val = rmse(y,pred)
    # MAE 는 scikit learn의 mean_absolute_error() 로 계산
    mae_val = mean_absolute_error(y,pred)
    print('RMSLE: {0:.3f}, RMSE: {1:.3F}, MAE: {2:.3F}'.format(rmsle_val, rmse_val, mae_val))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# 모델과 학습/테스트 데이터 셋을 입력하면 성능 평가 수치를 반환
def get_model_predict(model, X_train, X_test, y_train, y_test, is_expm1=False):
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    if is_expm1 :
        y_test = np.expm1(y_test)
        pred = np.expm1(pred)
    print('###',model.__class__.__name__,'###')
    evaluate_regr(y_test, pred)

# %%
# 랜덤 포레스트, GBM, XGBoost, LightGBM model 별로 평가 수행
rf_reg = RandomForestRegressor(n_estimators=500)
gbm_reg = GradientBoostingRegressor(n_estimators=500)
xgb_reg = XGBRegressor(n_estimators=500)
lgbm_reg = LGBMRegressor(n_estimators=500)

for model in [rf_reg, gbm_reg, xgb_reg, lgbm_reg]:
    # XGBoost의 경우 DataFrame이 입력 될 경우 버전에 따라 오류 발생 가능. ndarray로 변환.
    get_model_predict(model, X_train.values, X_test.values, y_train.values, y_test.values, is_expm1=True)
# Out:
# ### RandomForestRegressor ###
# RMSLE: 0.111, RMSE: 158.296, MAE: 129.922
# ### GradientBoostingRegressor ###
# RMSLE: 0.110, RMSE: 157.361, MAE: 120.527
# ### XGBRegressor ###
# RMSLE: 0.128, RMSE: 182.103, MAE: 160.439
# ### LGBMRegressor ###
# RMSLE: 0.141, RMSE: 207.677, MAE: 172.221
