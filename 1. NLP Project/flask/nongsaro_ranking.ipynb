# %%
import mariadb
import sys
import pandas as pd

# DB에서 공공데이터 농사로 테이블 불러오기
try:
    conn = mariadb.connect(
        user="root",
        password="1234",
        host="localhost",
        port=3306,
        database="puri"
    )
except mariadb.Error as e:
    print(f"Error connecting to MariaDB Platform: {e}")
    sys.exit(1)
df = pd.read_sql("select * from nongsaro", conn, index_col=None)
df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3852\54107564.py:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("select * from nongsaro", conn, index_col=None)
#                   식물명 컨텐츠 번호 관리수준         관리요구도  \
# 0               가울테리아  12938  경험자     낮음 (잘 견딤)
# 1                 개운죽  12954  초보자     낮음 (잘 견딤)
# 2         골드크레스트 '윌마'  12955  경험자  보통 (약간 잘 견딤)
# 3                공작야자  12957  경험자           필요함
# 4              관엽베고니아  12962  경험자  보통 (약간 잘 견딤)
# ..                ...    ...  ...           ...
# 212               황금죽  12932  경험자           필요함
# 213             후피향나무  12956  초보자     낮음 (잘 견딤)
# 214           흰꽃나도사프란  12920  초보자     낮음 (잘 견딤)
# 215  흰줄무늬달개비(트라데스칸티아)  12919  초보자  보통 (약간 잘 견딤)
# 216            히포에스테스  12901  초보자  보통 (약간 잘 견딤)
#
# ...

# %%
# 관리수준 값 별 수량
df.value_counts('관리수준')
data = df['관리수준'].value_counts()
labels = df['관리수준'].value_counts().index
print(labels)
print(df.value_counts('관리수준'))
# Out:
# Index(['경험자', '초보자', '내용없음', '전문가'], dtype='object')
# 관리수준
# 경험자     97
# 초보자     82
# 내용없음    29
# 전문가      9
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# 관리수준 열 값 분포 시각화
# data = df['관리수준'].value_counts()
# labels = df['관리수준'].value_counts().index
plt.pie(data, labels=('경험자', '초보자', '내용없음', '전문가'), autopct='%0.1f%%')
plt.show()

# %%
# 관리수준 단계별 랭킹 부여
# 전문적인 단계일수록 높은 숫자를 부여
df = df.replace({'관리수준':'초보자'}, 1)
df = df.replace({'관리수준':'경험자'}, 2)
df = df.replace({'관리수준':'전문가'}, 3)

# %%
# 관리요구도 열을 참고하여 관리수준 빈 값을 채워줌
df.loc[(df['관리요구도']=='특별 관리 요구')&(df['관리수준']=='내용없음'), '관리수준'] = 3
df.loc[(df['관리요구도']=='필요함')&(df['관리수준']=='내용없음'), '관리수준'] = 2
df.loc[(df['관리요구도']=='보통 (약간 잘 견딤)')&(df['관리수준']=='내용없음'), '관리수준'] = 1
df.loc[(df['관리요구도']=='낮음 (잘 견딤)')&(df['관리수준']=='내용없음'), '관리수준'] = 1

# %%
# 관리수준 빈 값이 없는 지 확인
df.value_counts('관리수준')
# Out:
# 관리수준
# 2    110
# 1     97
# 3     10
# dtype: int64

# %%
df[df['관리수준']=='내용없음']
# Out:
# Empty DataFrame
# Columns: [식물명, 컨텐츠 번호, 관리수준, 관리요구도, 광요구도, 배치장소, 생장속도, 생육적온, 겨울최저온도, 습도, 비료, 토양, 물주기-봄, 물주기-여름, 물주기-가을, 물주기-겨울, 병충해, url]
# Index: []

# %%
data = df['관리수준'].value_counts()
labels = df['관리수준'].value_counts().index
plt.pie(data, labels=('2', '1', '3'), autopct='%0.1f%%')
plt.show()

# %%
# 관리요구도 값 별 수량
df.value_counts('관리요구도')
data = df['관리요구도'].value_counts()
labels = df['관리요구도'].value_counts().index
print(labels)
print(df.value_counts('관리요구도'))
# Out:
# Index(['필요함', '보통 (약간 잘 견딤)', '낮음 (잘 견딤)', '특별 관리 요구'], dtype='object')
# 관리요구도
# 필요함             84
# 보통 (약간 잘 견딤)    77
# 낮음 (잘 견딤)       50
# 특별 관리 요구         6
# dtype: int64

# %%
plt.pie(data, labels=('필요함', '보통 (약간 잘 견딤)', '낮음 (잘 견딤)', '특별 관리 요구'), autopct='%0.1f%%')
plt.show()

# %%
# 관리요구도 단계별 랭킹 부여
# 전문적인 단계일수록 높은 숫자를 부여
df = df.replace({'관리요구도':'낮음 (잘 견딤)'}, 1)
df = df.replace({'관리요구도':'보통 (약간 잘 견딤)'}, 2)
df = df.replace({'관리요구도':'필요함'}, 3)
df = df.replace({'관리요구도':'특별 관리 요구'}, 4)

# %%
# 광요구도 값 별 수량
df.value_counts('광요구도')
data = df['광요구도'].value_counts()
labels = df['광요구도'].value_counts().index
print(labels)
print(df.value_counts('광요구도'))
# Out:
# Index(['중간 광도(800~1,500 Lux),높은 광도(1,500~10,000 Lux)',
#        '낮은 광도(300~800 Lux),중간 광도(800~1,500 Lux),높은 광도(1,500~10,000 Lux)',
#        '높은 광도(1,500~10,000 Lux)', '중간 광도(800~1,500 Lux)',
#        '낮은 광도(300~800 Lux),중간 광도(800~1,500 Lux)'],
#       dtype='object')
# 광요구도
# 중간 광도(800~1,500 Lux),높은 광도(1,500~10,000 Lux)                       157
# 낮은 광도(300~800 Lux),중간 광도(800~1,500 Lux),높은 광도(1,500~10,000 Lux)     33
# 높은 광도(1,500~10,000 Lux)                                             22
# 중간 광도(800~1,500 Lux)                                                 4
# 낮은 광도(300~800 Lux),중간 광도(800~1,500 Lux)                              1
# dtype: int64

# %%
plt.pie(data, labels=('중간 높음', '낮음 중간 높음', '높음', '중간', '낮음 중간'), autopct='%0.1f%%')
plt.show()

# %%
# 광요구도 단계별 랭킹 부여
# 모든 범위 포함을 가장 쉬운 1로 부여, 이후 광요구도가 높을수록 큰 숫자 부여
df = df.replace({'광요구도':'낮은 광도(300~800 Lux),중간 광도(800~1,500 Lux),높은 광도(1,500~10,000 Lux)'}, 1)
df = df.replace({'광요구도':'낮은 광도(300~800 Lux),중간 광도(800~1,500 Lux)'}, 2)
df = df.replace({'광요구도':'중간 광도(800~1,500 Lux)'}, 3)
df = df.replace({'광요구도':'중간 광도(800~1,500 Lux),높은 광도(1,500~10,000 Lux)'}, 4)
df = df.replace({'광요구도':'높은 광도(1,500~10,000 Lux)'}, 5)

# %%
df.value_counts('배치장소')
data = df['배치장소'].value_counts()
labels = df['배치장소'].value_counts().index
print(labels)
print(df.value_counts('배치장소'))
# Out:
# Index(['거실 창측 (실내깊이 150~300cm),발코니 내측 (실내깊이 50~150cm),발코니 창측 (실내깊이 0~50cm)',
#        '거실 내측 (실내깊이 300~500cm),거실 창측 (실내깊이 150~300cm),발코니 내측 (실내깊이 50~150cm),발코니 창측 (실내깊이 0~50cm)',
#        '거실 내측 (실내깊이 300~500cm),거실 창측 (실내깊이 150~300cm),발코니 내측 (실내깊이 50~150cm)',
#        '실내 어두운 곳 (실내깊이 500 이상cm),거실 내측 (실내깊이 300~500cm),거실 창측 (실내깊이 150~300cm),발코니 내측 (실내깊이 50~150cm),발코니 창측 (실내깊이 0~50cm)',
#        '발코니 내측 (실내깊이 50~150cm),발코니 창측 (실내깊이 0~50cm)',
#        '거실 창측 (실내깊이 150~300cm),발코니 내측 (실내깊이 50~150cm)',
#        '실내 어두운 곳 (실내깊이 500 이상cm),거실 내측 (실내깊이 300~500cm),거실 창측 (실내깊이 150~300cm),발코니 내측 (실내깊이 50~150cm)',
#        '거실 내측 (실내깊이 300~500cm),발코니 내측 (실내깊이 50~150cm),발코니 창측 (실내깊이 0~50cm)',
#        '발코니 창측 (실내깊이 0~50cm)'],
#       dtype='object')
# 배치장소
# 거실 창측 (실내깊이 150~300cm),발코니 내측 (실내깊이 50~150cm),발코니 창측 (실내깊이 0~50cm)                                                    115
# ...

# %%
plt.pie(data, labels=('거실 창측 (실내깊이 150~300cm),발코니 내측 (실내깊이 50~150cm),발코니 창측 (실내깊이 0~50cm)',
       '거실 내측 (실내깊이 300~500cm),거실 창측 (실내깊이 150~300cm),발코니 내측 (실내깊이 50~150cm),발코니 창측 (실내깊이 0~50cm)',
       '거실 내측 (실내깊이 300~500cm),거실 창측 (실내깊이 150~300cm),발코니 내측 (실내깊이 50~150cm)',
       '실내 어두운 곳 (실내깊이 500 이상cm),거실 내측 (실내깊이 300~500cm),거실 창측 (실내깊이 150~300cm),발코니 내측 (실내깊이 50~150cm),발코니 창측 (실내깊이 0~50cm)',
       '발코니 내측 (실내깊이 50~150cm),발코니 창측 (실내깊이 0~50cm)',
       '거실 창측 (실내깊이 150~300cm),발코니 내측 (실내깊이 50~150cm)',
       '실내 어두운 곳 (실내깊이 500 이상cm),거실 내측 (실내깊이 300~500cm),거실 창측 (실내깊이 150~300cm),발코니 내측 (실내깊이 50~150cm)',
       '거실 내측 (실내깊이 300~500cm),발코니 내측 (실내깊이 50~150cm),발코니 창측 (실내깊이 0~50cm)',
       '발코니 창측 (실내깊이 0~50cm)'), 
        autopct='%0.1f%%')
plt.show()

# %%
# 배치장소 단계별 랭킹 부여 유보
# 범위에서 분류기준을 찾기 어려움

# %%
df.value_counts('생장속도')
# Out:
# 생장속도
# 내용없음    83
# 보통      76
# 느림      36
# 빠름      22
# dtype: int64

# %%
data = df['생장속도'].value_counts()
labels = df['생장속도'].value_counts().index
plt.pie(data, labels=('내용없음', '보통', '느림', '빠름'), autopct='%0.1f%%')
plt.show()

# %%
df.value_counts('생육적온')
data = df['생육적온'].value_counts()
labels = df['생육적온'].value_counts().index
print(labels)
print(df.value_counts('생육적온'))
# Out:
# Index(['21~25℃', '16~20℃', '10~15℃', '내용없음'], dtype='object')
# 생육적온
# 21~25℃    130
# 16~20℃     84
# 10~15℃      2
# 내용없음        1
# dtype: int64

# %%
plt.pie(data, labels=('21~25℃', '16~20℃', '10~15℃', '내용없음'), autopct='%0.1f%%')
plt.show()

# %%
# 생육적온 결측치 탐색
df[df['생육적온']=='내용없음']
# Out:
#           식물명 컨텐츠 번호 관리수준  관리요구도  광요구도  \
# 103  소피아 고무나무  19703    2      3     1
#
#                                                   배치장소 생장속도  생육적온  겨울최저온도  \
# 103  거실 내측 (실내깊이 300~500cm),거실 창측 (실내깊이 150~300cm),...   보통  내용없음  13℃ 이상
#
#            습도          비료    토양                물주기-봄               물주기-여름  \
# 103  40 ~ 70%  비료를 보통 요구함  내용없음  토양 표면이 말랐을때 충분히 관수함  토양 표면이 말랐을때 충분히 관수함
#
#                   물주기-가을                 물주기-겨울   병충해  \
# 103  토양 표면이 말랐을때 충분히 관수함  화분 흙 대부분 말랐을때 충분히 관수함  내용없음
#
#                                                    url
# 103  https://www.nongsaro.go.kr/cms_contents/301/19...

# %%
# 겨울최저온도 중간값임을 참고하여 생육적온 중간값을 부여
df.loc[(df['겨울최저온도']=='13℃ 이상')&(df['생육적온']=='내용없음'), '생육적온'] = '21~25℃'

# %%
# 생육적온 단계별 랭킹 부여
# 온도가 높을수록 높은 숫자를 부여
df = df.replace({'생육적온':'10~15℃'}, 1)
df = df.replace({'생육적온':'16~20℃'}, 2)
df = df.replace({'생육적온':'21~25℃'}, 3)

# %%
df.value_counts('겨울최저온도')
data = df['겨울최저온도'].value_counts()
labels = df['겨울최저온도'].value_counts().index
print(labels)
print(df.value_counts('겨울최저온도'))
# Out:
# Index(['13℃ 이상', '5℃', '10℃', '0℃ 이하', '7℃'], dtype='object')
# 겨울최저온도
# 13℃ 이상    124
# 5℃         31
# 10℃        28
# 0℃ 이하      22
# 7℃         12
# dtype: int64

# %%
plt.pie(data, labels=('13℃ 이상', '5℃', '10℃', '0℃ 이하', '7℃'), autopct='%0.1f%%')
plt.show()

# %%
# 겨울최저온도 단계별 랭킹 부여
# 온도가 높을수록 높은 숫자를 부여
df = df.replace({'겨울최저온도':'0℃ 이하'}, 1)
df = df.replace({'겨울최저온도':'5℃'}, 2)
df = df.replace({'겨울최저온도':'7℃'}, 3)
df = df.replace({'겨울최저온도':'10℃'}, 4)
df = df.replace({'겨울최저온도':'13℃ 이상'}, 5)

# %%
df.value_counts('비료')
data = df['비료'].value_counts()
labels = df['비료'].value_counts().index
print(labels)
print(df.value_counts('비료'))
# Out:
# Index(['비료를 보통 요구함', '내용없음', '비료를 거의 요구하지않음', '비료를 많이 요구함',
#        '비료를 보통 요구함 (수용성비료 2주에 한번 줌)', '보통 요구함', '비료를 보통 요구함 (2회/년, 4월, 7월)',
#        '비료를 보통 요구함(봄~가을 완효성비료를 규칙적으로 줌)',
#        '비료를 보통 요구함(봄, 여름에 수용성 비료를 2주에 한번 줌)',
#        '비료를 보통 요구함 (가을~봄 한달에 한번 수용성 비료 줌)', '비료를 보통 요구함 (수용성비료를 2~3개월에 한번씩 줌)',
#        '비료를 보통 요구함(완효성 비료를 한달에 한번 줌)', '비료를 보통 요구함 (유기비료, 수용성비료는 2주에 한번 줌)',
#        '비료를 보통 요구함 (봄부터 초가을까지 한달에 1번 정도 줌)',
#        '비료를 보통 요구함(반희석한 수용성비료를 봄, 여름 2주에 한번 줌)',
#        '비료를 보통 요구함, 새 잎이 나올 때에는 주 1회 낮은 농도로 액비를 주고 겨울에는 월 1회 정도로 준다',
#        '꽃이 진 후 시비', '비료를 보통 요구함(2회/년, 4월, 7월)', '비료를 보통 요구함 (1회/년, 봄)',
#        '비료를 보통 요구함 (2주, 개화시 제외)', '비료를 보통 요구함 (봄, 여름에 수용성 비료를 2주에 한번 줌)',
#        '비료를 거의 요구하지않음 (2회/년, 4월, 7월 수용성비료 줌)',
#        '비료를 보통 요구함 (2~3개월에 한번씩 수용성 비료 줌)', '비료를 보통 요구함(가을에 수용성비료를 2주에 한번 줌)',
#        '비료를 보통 요구함(봄과 가을에 수용성비료를 2주에 한번 줌)',
#        '비료를 보통 요구함(봄과 여름 2주에 한번씩 수용성 비료 줌)', '비료를 보통 요구함(동절기 비료주지 않음)',
# ...

# %%
plt.pie(data, labels=('비료를 보통 요구함', '내용없음', '비료를 거의 요구하지않음', '비료를 많이 요구함',
       '비료를 보통 요구함 (수용성비료 2주에 한번 줌)', '보통 요구함', '비료를 보통 요구함 (2회/년, 4월, 7월)',
       '비료를 보통 요구함(봄~가을 완효성비료를 규칙적으로 줌)',
       '비료를 보통 요구함(봄, 여름에 수용성 비료를 2주에 한번 줌)',
       '비료를 보통 요구함 (가을~봄 한달에 한번 수용성 비료 줌)', '비료를 보통 요구함 (수용성비료를 2~3개월에 한번씩 줌)',
       '비료를 보통 요구함(완효성 비료를 한달에 한번 줌)', '비료를 보통 요구함 (유기비료, 수용성비료는 2주에 한번 줌)',
       '비료를 보통 요구함 (봄부터 초가을까지 한달에 1번 정도 줌)',
       '비료를 보통 요구함(반희석한 수용성비료를 봄, 여름 2주에 한번 줌)',
       '비료를 보통 요구함, 새 잎이 나올 때에는 주 1회 낮은 농도로 액비를 주고 겨울에는 월 1회 정도로 준다',
       '꽃이 진 후 시비', '비료를 보통 요구함(2회/년, 4월, 7월)', '비료를 보통 요구함 (1회/년, 봄)',
       '비료를 보통 요구함 (2주, 개화시 제외)', '비료를 보통 요구함 (봄, 여름에 수용성 비료를 2주에 한번 줌)',
       '비료를 거의 요구하지않음 (2회/년, 4월, 7월 수용성비료 줌)',
       '비료를 보통 요구함 (2~3개월에 한번씩 수용성 비료 줌)', '비료를 보통 요구함(가을에 수용성비료를 2주에 한번 줌)',
       '비료를 보통 요구함(봄과 가을에 수용성비료를 2주에 한번 줌)',
       '비료를 보통 요구함(봄과 여름 2주에 한번씩 수용성 비료 줌)', '비료를 보통 요구함(동절기 비료주지 않음)',
       '비료를 보통 요구함(수용성비료 2주에 한번 줌)', '비료를 보통 요구함(봄~가을 완효성비료를 규칙적으로 주고 겨울에 중단)',
       '비료를 보통 요구함. (수용성비료 2주에 한번 줌)', '많이 요구함 (유기물이 풍부, 성장기간동안 산성비료 2주에 1번)',
       '보통 요구함 (수용성비료를 봄과 여름에 격주로 줌)', '비료를 거의 요구하지않음 (2회/년, 4월, 7월)',
       '연중 개화하는 식물이므로 규칙적인 시비가 필요하다.', '비료를 거의 요구하지않음 (1회/년, 봄)',
       '2주 1회 정도 복합비료 필요'), autopct='%0.1f%%')
plt.show()

# %%
df.value_counts('토양')
data = df['토양'].value_counts()
labels = df['토양'].value_counts().index
print(labels)
print(df.value_counts('토양'))
# Out:
# Index(['내용없음', '산성, 중성, 알칼리성 / 양질토, 모래', '중성,산성 / 배수 잘 됨 / 타입-Loam, Sand',
#        '포름알데히드', '화분용영양토', '화분용 영양토', '산성, 중성 / 양질토, 모래',
#        '산성, 중성, 알칼리성 / 양질토, 모래 / 건조한토양', '포름알데히드, 벤젠, 톨루엔, 자일렌, 트리클로로 에틸렌',
#        '중성,산성,알칼리성 / 배수 잘 됨 / 타입-Loam, Sand', '중성 / 배수 잘 됨 / 타입-Loam',
#        '포름알데히드, 벤젠', '물빠짐이 좋은 토양 / 모래, 경석, 하이드로볼', '중성(pH 6-7) / 모래, 식양토',
#        '산성, 중성 / 양질토, 모래 / 건조한토양', '산성, 중성, 알칼리성 / 점토, 양질토, 모래 / 건조한토양',
#        '산성, 중성, 알칼리성 / 양질토, 모래 / 건조하고 배수가 잘되는 토양',
#        '산성 / 양질토 / 건조하고 배수가 잘되는 토양', '산성, 중성 / 점토, 양질토, 모래', '가볍고 건조한 토양',
#        '양질토, 모래', '포름알데히드, 자일렌', '산성, 중성, 알칼리 / 양질토, 모래 / 건조한 토양',
#        '배수가 잘되는 토양이 좋다.', '부식토', '배수 잘 됨',
#        '증산율이 높기 때문에 수경재배나 지하관수로도 키울 수 있다. 수경재배나 지하관수를 하면', '포름알데히드, 자일렌, 암모니아',
#        '중성,산성 / 배수 잘 됨 / 타입-Loam', '산성, 중성, 알칼리성 / 점토, 양질토, 모래',
#        '토양 : 중성,산성 / 배수 잘 됨 (Loam,Sand)', '배수 잘 됨 / 모래', '산성, 중성 / 점토, 양질토',
#        '토양-중성,산성/배수잘됨/타입-Loam', '중성,산성 / 배수 잘 됨 / 타입-Loam, Clay',
# ...

# %%
plt.pie(data, labels=('내용없음', '산성, 중성, 알칼리성 / 양질토, 모래', '중성,산성 / 배수 잘 됨 / 타입-Loam, Sand',
       '포름알데히드', '화분용영양토', '화분용 영양토', '산성, 중성 / 양질토, 모래',
       '산성, 중성, 알칼리성 / 양질토, 모래 / 건조한토양', '포름알데히드, 벤젠, 톨루엔, 자일렌, 트리클로로 에틸렌',
       '중성,산성,알칼리성 / 배수 잘 됨 / 타입-Loam, Sand', '중성 / 배수 잘 됨 / 타입-Loam',
       '포름알데히드, 벤젠', '물빠짐이 좋은 토양 / 모래, 경석, 하이드로볼', '중성(pH 6-7) / 모래, 식양토',
       '산성, 중성 / 양질토, 모래 / 건조한토양', '산성, 중성, 알칼리성 / 점토, 양질토, 모래 / 건조한토양',
       '산성, 중성, 알칼리성 / 양질토, 모래 / 건조하고 배수가 잘되는 토양',
       '산성 / 양질토 / 건조하고 배수가 잘되는 토양', '산성, 중성 / 점토, 양질토, 모래', '가볍고 건조한 토양',
       '양질토, 모래', '포름알데히드, 자일렌', '산성, 중성, 알칼리 / 양질토, 모래 / 건조한 토양',
       '배수가 잘되는 토양이 좋다.', '부식토', '배수 잘 됨',
       '증산율이 높기 때문에 수경재배나 지하관수로도 키울 수 있다. 수경재배나 지하관수를 하면', '포름알데히드, 자일렌, 암모니아',
       '중성,산성 / 배수 잘 됨 / 타입-Loam', '산성, 중성, 알칼리성 / 점토, 양질토, 모래',
       '토양 : 중성,산성 / 배수 잘 됨 (Loam,Sand)', '배수 잘 됨 / 모래', '산성, 중성 / 점토, 양질토',
       '토양-중성,산성/배수잘됨/타입-Loam', '중성,산성 / 배수 잘 됨 / 타입-Loam, Clay',
       '중성 / 배수 잘 됨 / 타입-Loam, Sand',
       '중성,산성,알칼리성 / 배수 잘 됨 / 타입-Clay, Loam, Sand',
       '중성 / 배수정도 보통 / 타입 - Loam, Sand',
       '건조에 강한 식물이므로 겉흙이 완전히 마르면 관수하며 온도가 낮은 환경에서는 특별히 흙을 건조하게 관리한다.',
       '유기질이 풍부한 배합토로 만든 토양에서 기른다.', '난석 4:부엽토 3:강모래 3', '배수가 잘 되는 토양',
       '양토(산성, 중성), 점토, 모래, 건조토양', '물빠짐이 좋으면서 보수력을 지닌 토양',
       '물빠짐이 좋고 다소 보수력이 있는 토양',
       '가볍고, 건조잘되는것, 양질토, 모래, 산도(알칼리, 중성), 일반화분용토양(토양자체가 단단하면 모래 또는 펄라이트, 피트모스를 추가하여 흙을 만듬)',
       '건조하고 가벼운 토양 / 산성, 알카리', '물빠짐이 좋은토양, 양질토, 모래, 중성(산도)', '건조한 토양',
       '좋은 배수와 균등 습한 토양 / 양질토, 모래 / 중성, 알카리', '산성, 중성 / 양질토', '중성 / 양질토, 모래',
       '포름알데히드, 벤젠, 톨루엔, 트리클로로 에틸렌, 암모니아'), autopct='%0.1f%%')
plt.show()

# %%
# 토양과 비료는 랭킹화하기에 적절한 데이터가 아니어서 사용하지 않음.

# %%
df.value_counts('습도')
data = df['습도'].value_counts()
labels = df['습도'].value_counts().index
print(labels)
print(df.value_counts('습도'))
# Out:
# Index(['40 ~ 70%', '70% 이상', '40% 미만', '내용없음'], dtype='object')
# 습도
# 40 ~ 70%    191
# 70% 이상       17
# 40% 미만        7
# 내용없음          2
# dtype: int64

# %%
plt.pie(data, labels=('40 ~ 70%', '70% 이상', '40% 미만', '내용없음'), autopct='%0.1f%%')
plt.show()

# %%
# 습도 결측치 탐색
df[df['습도']=='내용없음']
# Out:
#        식물명 컨텐츠 번호 관리수준  관리요구도  광요구도  \
# 18     나한송  13203    1      1     4
# 170  클레마티스  13255    2      1     5
#
#                                                   배치장소 생장속도  생육적온  겨울최저온도  \
# 18   거실 창측 (실내깊이 150~300cm),발코니 내측 (실내깊이 50~150cm),...   느림     1       2
# 170                               발코니 창측 (실내깊이 0~50cm)   빠름     3       1
#
#        습도                비료                                         토양  \
# 18   내용없음            보통 요구함  중성,산성,알칼리성 / 배수 잘 됨 / 타입-Clay, Loam, Sand
# 170  내용없음  2주 1회 정도 복합비료 필요                                       내용없음
#
#                           물주기-봄                      물주기-여름  \
# 18   흙을 촉촉하게 유지함(물에 잠기지 않도록 주의)  흙을 촉촉하게 유지함(물에 잠기지 않도록 주의)
# 170  흙을 촉촉하게 유지함(물에 잠기지 않도록 주의)  흙을 촉촉하게 유지함(물에 잠기지 않도록 주의)
#
#                          물주기-가을               물주기-겨울   병충해  \
# 18   흙을 촉촉하게 유지함(물에 잠기지 않도록 주의)  토양 표면이 말랐을때 충분히 관수함  내용없음
# 170  흙을 촉촉하게 유지함(물에 잠기지 않도록 주의)  토양 표면이 말랐을때 충분히 관수함  내용없음
#
# ...

# %%
# 물주기값 중간값임을 참고하여 습도 중간값을 부여
df.loc[(df['물주기-봄']=='흙을 촉촉하게 유지함(물에 잠기지 않도록 주의)')&(df['습도']=='내용없음'), '습도'] = '40 ~ 70%'

# %%
# 겨울최저온도 단계별 랭킹 부여
# 온도가 높을수록 높은 숫자를 부여
df = df.replace({'습도':'40% 미만'}, 1)
df = df.replace({'습도':'40 ~ 70%'}, 2)
df = df.replace({'습도':'70% 이상'}, 3)

# %%
df.value_counts('물주기-봄')
data = df['물주기-봄'].value_counts()
labels = df['물주기-봄'].value_counts().index
print(labels)
print(df.value_counts('물주기-봄'))
# Out:
# Index(['토양 표면이 말랐을때 충분히 관수함', '흙을 촉촉하게 유지함(물에 잠기지 않도록 주의)',
#        '화분 흙 대부분 말랐을때 충분히 관수함', '내용없음', '항상 흙을 축축하게 유지함(물에 잠김)'],
#       dtype='object')
# 물주기-봄
# 토양 표면이 말랐을때 충분히 관수함           146
# 흙을 촉촉하게 유지함(물에 잠기지 않도록 주의)     46
# 화분 흙 대부분 말랐을때 충분히 관수함          15
# 내용없음                            9
# 항상 흙을 축축하게 유지함(물에 잠김)           1
# dtype: int64

# %%
plt.pie(data, labels=('토양 표면이 말랐을때 충분히 관수함', '흙을 촉촉하게 유지함(물에 잠기지 않도록 주의)',
       '화분 흙 대부분 말랐을때 충분히 관수함', '내용없음', '항상 흙을 축축하게 유지함(물에 잠김)'), autopct='%0.1f%%')
plt.show()

# %%
# 물주기-봄 결측치 탐색
# 다른 컬럼들도 값이 없어서 결측치를 채우기 힘듬
df[df['물주기-봄']=='내용없음']
# Out:
#               식물명 컨텐츠 번호 관리수준  관리요구도  광요구도  \
# 68         무늬알피니아  18596    1      1     4
# 74          뮤렌베키아  18649    1      1     2
# 107      수염 틸란드시아  19711    2      3     4
# 133  에메랄드리플 페페로미아  18654    2      3     4
# 142     움벨라타 고무나무  18585    2      2     4
# 153        종려방동사니  16036    2      2     4
# 174           톨미아  13003    2      3     4
# 208       호야 엑소티카  12975    2      2     4
# 210      홀리아페페로미아  12971    2      3     4
#
#                                                   배치장소  생장속도  생육적온  겨울최저온도  \
# 68   거실 창측 (실내깊이 150~300cm),발코니 내측 (실내깊이 50~150cm),...  내용없음     3       5
# 74   거실 내측 (실내깊이 300~500cm),거실 창측 (실내깊이 150~300cm),...  내용없음     2       4
# 107  거실 내측 (실내깊이 300~500cm),거실 창측 (실내깊이 150~300cm),...    느림     3       5
# 133  거실 내측 (실내깊이 300~500cm),거실 창측 (실내깊이 150~300cm),...    느림     3       5
# 142  거실 창측 (실내깊이 150~300cm),발코니 내측 (실내깊이 50~150cm),...  내용없음     3       5
# 153  거실 창측 (실내깊이 150~300cm),발코니 내측 (실내깊이 50~150cm),...  내용없음     2       4
# ...

# %%
# 물주기-봄 단계별 랭킹 부여
# 물을 많이 줘야 할 수록 높은 숫자를 부여
df = df.replace({'물주기-봄':'화분 흙 대부분 말랐을때 충분히 관수함'}, 1)
df = df.replace({'물주기-봄':'토양 표면이 말랐을때 충분히 관수함'}, 2)
df = df.replace({'물주기-봄':'흙을 촉촉하게 유지함(물에 잠기지 않도록 주의)'}, 3)
df = df.replace({'물주기-봄':'항상 흙을 축축하게 유지함(물에 잠김)'}, 4)

# %%
df.value_counts('물주기-여름')
data = df['물주기-여름'].value_counts()
labels = df['물주기-여름'].value_counts().index
print(labels)
print(df.value_counts('물주기-여름'))
# Out:
# Index(['토양 표면이 말랐을때 충분히 관수함', '흙을 촉촉하게 유지함(물에 잠기지 않도록 주의)', '내용없음',
#        '화분 흙 대부분 말랐을때 충분히 관수함', '항상 흙을 축축하게 유지함(물에 잠김)'],
#       dtype='object')
# 물주기-여름
# 토양 표면이 말랐을때 충분히 관수함           152
# 흙을 촉촉하게 유지함(물에 잠기지 않도록 주의)     48
# 내용없음                           10
# 화분 흙 대부분 말랐을때 충분히 관수함           6
# 항상 흙을 축축하게 유지함(물에 잠김)           1
# dtype: int64

# %%
plt.pie(data, labels=('토양 표면이 말랐을때 충분히 관수함', '흙을 촉촉하게 유지함(물에 잠기지 않도록 주의)', '내용없음',
       '화분 흙 대부분 말랐을때 충분히 관수함', '항상 흙을 축축하게 유지함(물에 잠김)'), autopct='%0.1f%%')
plt.show()

# %%
# 물주기-여름 결측치 탐색
# 다른 컬럼들도 값이 없어서 결측치를 채우기 힘듬
df[df['물주기-여름']=='내용없음']
# Out:
#               식물명 컨텐츠 번호 관리수준  관리요구도  광요구도  \
# 68         무늬알피니아  18596    1      1     4
# 74          뮤렌베키아  18649    1      1     2
# 107      수염 틸란드시아  19711    2      3     4
# 114          시클라멘  19707    3      3     4
# 133  에메랄드리플 페페로미아  18654    2      3     4
# 142     움벨라타 고무나무  18585    2      2     4
# 153        종려방동사니  16036    2      2     4
# 174           톨미아  13003    2      3     4
# 208       호야 엑소티카  12975    2      2     4
# 210      홀리아페페로미아  12971    2      3     4
#
#                                                   배치장소  생장속도  생육적온  겨울최저온도  \
# 68   거실 창측 (실내깊이 150~300cm),발코니 내측 (실내깊이 50~150cm),...  내용없음     3       5
# 74   거실 내측 (실내깊이 300~500cm),거실 창측 (실내깊이 150~300cm),...  내용없음     2       4
# 107  거실 내측 (실내깊이 300~500cm),거실 창측 (실내깊이 150~300cm),...    느림     3       5
# 114  거실 창측 (실내깊이 150~300cm),발코니 내측 (실내깊이 50~150cm),...    느림     2       3
# 133  거실 내측 (실내깊이 300~500cm),거실 창측 (실내깊이 150~300cm),...    느림     3       5
# ...

# %%
# 물주기값 중간값임을 참고하여 습도 중간값을 부여
df.loc[(df['물주기-봄']=='토양 표면이 말랐을때 충분히 관수함')&(df['물주기-여름']=='내용없음'), '물주기-여름'] = '토양 표면이 말랐을때 충분히 관수함'

# %%
# 물주기-여름 단계별 랭킹 부여
# 물을 많이 줘야 할 수록 높은 숫자를 부여
df = df.replace({'물주기-여름':'화분 흙 대부분 말랐을때 충분히 관수함'}, 1)
df = df.replace({'물주기-여름':'토양 표면이 말랐을때 충분히 관수함'}, 2)
df = df.replace({'물주기-여름':'흙을 촉촉하게 유지함(물에 잠기지 않도록 주의)'}, 3)
df = df.replace({'물주기-여름':'항상 흙을 축축하게 유지함(물에 잠김)'}, 4)

# %%
df.value_counts('물주기-가을')
data = df['물주기-가을'].value_counts()
labels = df['물주기-가을'].value_counts().index
print(labels)
print(df.value_counts('물주기-가을'))
# Out:
# Index(['토양 표면이 말랐을때 충분히 관수함', '흙을 촉촉하게 유지함(물에 잠기지 않도록 주의)', '내용없음',
#        '화분 흙 대부분 말랐을때 충분히 관수함', '항상 흙을 축축하게 유지함(물에 잠김)'],
#       dtype='object')
# 물주기-가을
# 토양 표면이 말랐을때 충분히 관수함           158
# 흙을 촉촉하게 유지함(물에 잠기지 않도록 주의)     42
# 내용없음                            9
# 화분 흙 대부분 말랐을때 충분히 관수함           7
# 항상 흙을 축축하게 유지함(물에 잠김)           1
# dtype: int64

# %%
plt.pie(data, labels=('토양 표면이 말랐을때 충분히 관수함', '흙을 촉촉하게 유지함(물에 잠기지 않도록 주의)', '내용없음',
       '화분 흙 대부분 말랐을때 충분히 관수함', '항상 흙을 축축하게 유지함(물에 잠김)'), autopct='%0.1f%%')
plt.show()

# %%
# 물주기-가을 단계별 랭킹 부여
# 물을 많이 줘야 할 수록 높은 숫자를 부여
df = df.replace({'물주기-가을':'화분 흙 대부분 말랐을때 충분히 관수함'}, 1)
df = df.replace({'물주기-가을':'토양 표면이 말랐을때 충분히 관수함'}, 2)
df = df.replace({'물주기-가을':'흙을 촉촉하게 유지함(물에 잠기지 않도록 주의)'}, 3)
df = df.replace({'물주기-가을':'항상 흙을 축축하게 유지함(물에 잠김)'}, 4)

# %%
df.value_counts('물주기-겨울')
data = df['물주기-겨울'].value_counts()
labels = df['물주기-겨울'].value_counts().index
print(labels)
print(df.value_counts('물주기-겨울'))
# Out:
# Index(['화분 흙 대부분 말랐을때 충분히 관수함', '토양 표면이 말랐을때 충분히 관수함', '내용없음',
#        '흙을 촉촉하게 유지함(물에 잠기지 않도록 주의)'],
#       dtype='object')
# 물주기-겨울
# 화분 흙 대부분 말랐을때 충분히 관수함         143
# 토양 표면이 말랐을때 충분히 관수함            64
# 내용없음                            9
# 흙을 촉촉하게 유지함(물에 잠기지 않도록 주의)      1
# dtype: int64

# %%
plt.pie(data, labels=('화분 흙 대부분 말랐을때 충분히 관수함', '토양 표면이 말랐을때 충분히 관수함', '내용없음',
       '흙을 촉촉하게 유지함(물에 잠기지 않도록 주의)'), autopct='%0.1f%%')
plt.show()

# %%
# 물주기-겨울 단계별 랭킹 부여
# 물을 많이 줘야 할 수록 높은 숫자를 부여
df = df.replace({'물주기-겨울':'화분 흙 대부분 말랐을때 충분히 관수함'}, 1)
df = df.replace({'물주기-겨울':'토양 표면이 말랐을때 충분히 관수함'}, 2)
df = df.replace({'물주기-겨울':'흙을 촉촉하게 유지함(물에 잠기지 않도록 주의)'}, 3)
df = df.replace({'물주기-겨울':'항상 흙을 축축하게 유지함(물에 잠김)'}, 4)

# %%
df.value_counts('병충해')
data = df['병충해'].value_counts()
labels = df['병충해'].value_counts().index
print(labels)
print(df.value_counts('병충해'))
# Out:
# Index(['내용없음', '가정과 온실 도입시 유의 제거', '작은벌레, 삽주벌레 등 (가정과 온실 도입시 유의 제거)',
#        '깍지벌레, 개각충, 진딧물',
#        '습기가 많아서 민달팽이에 침해되기 쉬우므로 민달팽이가 붙으면 약을 뿌려 주도록 하고 과습에 의한 곰팡이병도 문제가 된다. 또, 건조할 때는 깍지벌레, 온실가루이, 가루깍지벌레 등이 발생한다.',
#        '온실가루이, 개각충, 진딧물', '깍지벌레, 개각충, 응애', '개각충, 응애', '깍지벌레, 개각충, 진딧물, 응애',
#        '깍지벌레', '깍지벌레, 응애', '응애', '온실가루이, 응애', '깍지벌레, 총채벌레',
#        '고온 건조할때 햇빛이 강한 곳에 두면, 잎이 떨어지거나 진딧물이 발생하므로 주의한다.', '개각충, 응애, 총채벌레',
#        '온실가루이, 깍지벌레,  응애', '깍지벌레, 진딧물', '깍지벌레, 개각충', '온실가루이, 깍지벌레, 개각충', '개각충',
#        '실내가 너무 건조하면 응애가 생길 수 있으며 잎 끝이 갈색으로 변한다.', '온실가루이, 개각충, 응애, 진딧물',
#        '일반적으로 병이나 해충이 없으나 매우 드물게 응애가 생기기도 한다.',
#        '질병 거의 없음 / 곤충에 약함 (가정과 온실 도입시 유의 제거)',
#        '개각충 등 (깨끗한 용기에 심기, 가정과 온실 도입시 유의 제거)',
#        '삽주벌레 등 (깨끗한 용기에 심기, 가정과 온실 도입시 유의 제거)', '진딧물',
#        '개각충 (가정과 온실 도입시 유의 제거)', '거미진드기, 작은벌레 등 (가정과 온실 도입시 유의 제거)',
#        '가정과 온실 도입시 벌레 확인!', '거미진드기 등 (가정과 온실 도입시 유의 제거)',
#        '거미진드기, 분질벌레, 삽주벌레(가정과 온실 도입시 유의 제거)', '관부썩음병',
# ...

# %%
plt.pie(data, labels=('내용없음', '가정과 온실 도입시 유의 제거', '작은벌레, 삽주벌레 등 (가정과 온실 도입시 유의 제거)',
       '깍지벌레, 개각충, 진딧물',
       '습기가 많아서 민달팽이에 침해되기 쉬우므로 민달팽이가 붙으면 약을 뿌려 주도록 하고 과습에 의한 곰팡이병도 문제가 된다. 또, 건조할 때는 깍지벌레, 온실가루이, 가루깍지벌레 등이 발생한다.',
       '온실가루이, 개각충, 진딧물', '깍지벌레, 개각충, 응애', '개각충, 응애', '깍지벌레, 개각충, 진딧물, 응애',
       '깍지벌레', '깍지벌레, 응애', '응애', '온실가루이, 응애', '깍지벌레, 총채벌레',
       '고온 건조할때 햇빛이 강한 곳에 두면, 잎이 떨어지거나 진딧물이 발생하므로 주의한다.', '개각충, 응애, 총채벌레',
       '온실가루이, 깍지벌레,  응애', '깍지벌레, 진딧물', '깍지벌레, 개각충', '온실가루이, 깍지벌레, 개각충', '개각충',
       '실내가 너무 건조하면 응애가 생길 수 있으며 잎 끝이 갈색으로 변한다.', '온실가루이, 개각충, 응애, 진딧물',
       '일반적으로 병이나 해충이 없으나 매우 드물게 응애가 생기기도 한다.',
       '질병 거의 없음 / 곤충에 약함 (가정과 온실 도입시 유의 제거)',
       '개각충 등 (깨끗한 용기에 심기, 가정과 온실 도입시 유의 제거)',
       '삽주벌레 등 (깨끗한 용기에 심기, 가정과 온실 도입시 유의 제거)', '진딧물',
       '개각충 (가정과 온실 도입시 유의 제거)', '거미진드기, 작은벌레 등 (가정과 온실 도입시 유의 제거)',
       '가정과 온실 도입시 벌레 확인!', '거미진드기 등 (가정과 온실 도입시 유의 제거)',
       '거미진드기, 분질벌레, 삽주벌레(가정과 온실 도입시 유의 제거)', '관부썩음병',
       '불소 화합물 독성 때문에 잎끝이 갈변되고 살충제로 인해 잎가장자리가 타기도 함. 응애, 깍지벌레 등, 과습이 심할 경우 부패, 시들, 잎반점 등 나타남.',
       '거미진드기 (실내나 온실 도입 전에 병충해 검사 요함.)', '실내나 온실 도입 전에 병충해 검사 요함',
       '깍지벌레, 개각충, 응애, 총채벌레'), autopct='%0.1f%%')
plt.show()

# %%
df = df.astype(str)
df
# Out:
#                   식물명 컨텐츠 번호 관리수준 관리요구도 광요구도  \
# 0               가울테리아  12938    2     1    4
# 1                 개운죽  12954    1     1    1
# 2         골드크레스트 '윌마'  12955    2     2    5
# 3                공작야자  12957    2     3    4
# 4              관엽베고니아  12962    2     2    4
# ..                ...    ...  ...   ...  ...
# 212               황금죽  12932    2     3    4
# 213             후피향나무  12956    1     1    5
# 214           흰꽃나도사프란  12920    1     1    5
# 215  흰줄무늬달개비(트라데스칸티아)  12919    1     2    4
# 216            히포에스테스  12901    1     2    4
#
#                                                   배치장소  생장속도 생육적온 겨울최저온도  \
# 0    거실 창측 (실내깊이 150~300cm),발코니 내측 (실내깊이 50~150cm),...    느림    2      1
# 1    거실 내측 (실내깊이 300~500cm),거실 창측 (실내깊이 150~300cm),...    보통    2      5
# 2    거실 창측 (실내깊이 150~300cm),발코니 내측 (실내깊이 50~150cm),...    보통    2      4
# 3    거실 창측 (실내깊이 150~300cm),발코니 내측 (실내깊이 50~150cm),...    보통    3      5
# ...

# %%
# 인덱스 열 추가
df = df.reset_index()

# %%
# 데이터프레임 컬럼 명 영어로 변경
df = df.rename(columns={'식물명':'plant_name'})
df = df.rename(columns={'컨텐츠 번호':'contents_num'})
df = df.rename(columns={'관리수준':'mng_level'})
df = df.rename(columns={'관리요구도':'mng_demand'})
df = df.rename(columns={'광요구도':'light_demand'})
df = df.rename(columns={'배치장소':'place_placement'})
df = df.rename(columns={'생장속도':'growth_rate'})
df = df.rename(columns={'생육적온':'op_temp'})
df = df.rename(columns={'겨울최저온도':'win_min_temp'})
df = df.rename(columns={'습도':'humdity'})
df = df.rename(columns={'비료':'fertilizer'})
df = df.rename(columns={'토양':'soil'})
df = df.rename(columns={'물주기-봄':'watering_spring'})
df = df.rename(columns={'물주기-여름':'watering_summer'})
df = df.rename(columns={'물주기-가을':'watering_autumn'})
df = df.rename(columns={'물주기-겨울':'watering_winter'})
df = df.rename(columns={'병충해':'disease'})

# %%
df
# Out:
#      index        plant_name contents_num mng_level mng_demand light_demand  \
# 0        0             가울테리아        12938         2          1            4
# 1        1               개운죽        12954         1          1            1
# 2        2       골드크레스트 '윌마'        12955         2          2            5
# 3        3              공작야자        12957         2          3            4
# 4        4            관엽베고니아        12962         2          2            4
# ..     ...               ...          ...       ...        ...          ...
# 212    212               황금죽        12932         2          3            4
# 213    213             후피향나무        12956         1          1            5
# 214    214           흰꽃나도사프란        12920         1          1            5
# 215    215  흰줄무늬달개비(트라데스칸티아)        12919         1          2            4
# 216    216            히포에스테스        12901         1          2            4
#
# ...

# %%
wat_df = df['watering_spring'] != df['watering_summer']

df[wat_df].count()
# Out:
# index              12
# plant_name         12
# contents_num       12
# mng_level          12
# mng_demand         12
# light_demand       12
# place_placement    12
# growth_rate        12
# op_temp            12
# win_min_temp       12
# humdity            12
# fertilizer         12
# soil               12
# watering_spring    12
# watering_summer    12
# watering_autumn    12
# watering_winter    12
# disease            12
# url                12
# dtype: int64

# %%
wat_df = df['watering_summer'] != df['watering_autumn']

df[wat_df].count()
# Out:
# index              8
# plant_name         8
# contents_num       8
# mng_level          8
# mng_demand         8
# light_demand       8
# place_placement    8
# growth_rate        8
# op_temp            8
# win_min_temp       8
# humdity            8
# fertilizer         8
# soil               8
# watering_spring    8
# watering_summer    8
# watering_autumn    8
# watering_winter    8
# disease            8
# url                8
# dtype: int64

# %%
wat_df = df['watering_spring'] != df['watering_autumn']

df[wat_df].count()
# Out:
# index              12
# plant_name         12
# contents_num       12
# mng_level          12
# mng_demand         12
# light_demand       12
# place_placement    12
# growth_rate        12
# op_temp            12
# win_min_temp       12
# humdity            12
# fertilizer         12
# soil               12
# watering_spring    12
# watering_summer    12
# watering_autumn    12
# watering_winter    12
# disease            12
# url                12
# dtype: int64

# %%
wat_df = df['watering_summer'] != df['watering_winter']

df[wat_df].count()
# Out:
# index              171
# plant_name         171
# contents_num       171
# mng_level          171
# mng_demand         171
# light_demand       171
# place_placement    171
# growth_rate        171
# op_temp            171
# win_min_temp       171
# humdity            171
# fertilizer         171
# soil               171
# watering_spring    171
# watering_summer    171
# watering_autumn    171
# watering_winter    171
# disease            171
# url                171
# dtype: int64

# %%
# 봄 여름 가을 겨울 물주기가 일치하지 못하는 식물이 많음
# 봄 기준으로 사용

# 추후 열 생성후 평균값을 사용하면 아래 코드 응용
# df.loc[df['first'] == df['second'], 'average'] = 'equal'

# %%
import pymysql
from sqlalchemy import create_engine
import mariadb

# mariaDB 접속하기
# MariaDB Connector using pymysql
engine = create_engine("mariadb+pymysql://root:1234@localhost:3306/puri")
# 커서
con = engine.connect()

# mariaDB에 저장하기
# name은 생성할 테이블명
# 이미 존재할 경우 새 것으로 대체
# index=False, 인덱스 제외
df.to_sql(name='nongsaro_rank', con=engine, if_exists='replace', index=False)
# Out:
# 217

# %%
#데이터 프레임을 엑셀로 추출
import xlwings as xw
xw.view(df)
